# %%
import numpy as np
from numpy.linalg import inv
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.stats import mannwhitneyu

# %%
df = pd.DataFrame({'Participant':np.arange(6),
                   'Rating': [3,4,2,6,2,5]})
df = df.set_index('Participant')

df2 = pd.DataFrame({'Participant':np.arange(6),
                   'Rating': [9,7,5,10,6,8]})

df2 = df2.set_index('Participant')

print(df)

print(df2)
# Out:
#              Rating
# Participant
# 0                 3
# 1                 4
# 2                 2
# 3                 6
# 4                 2
# 5                 5
#              Rating
# Participant
# 0                 9
# 1                 7
# 2                 5
# 3                10
# 4                 6
# 5                 8

# %%
df['Product'] = 1
df2['Product'] = 2

df_compare = pd.concat([df,df2])

df_compare['Rank'] = df_compare.Rating.rank()

df_compare
# Out:
#              Rating  Product  Rank
# Participant
# 0                 3        1   3.0
# 1                 4        1   4.0
# 2                 2        1   1.5
# 3                 6        1   7.5
# 4                 2        1   1.5
# 5                 5        1   5.5
# 0                 9        2  11.0
# 1                 7        2   9.0
# 2                 5        2   5.5
# 3                10        2  12.0
# 4                 6        2   7.5
# 5                 8        2  10.0

# %%
T1 = df_compare.groupby('Product').get_group(1)['Rank'].sum()

print(T1)

T2 = df_compare.groupby('Product').get_group(2)['Rank'].sum()

print(T2)
# Out:
# 23.0
# 55.0

# %%
n1 = 6         
n2 = 6         
nx = 6 #because the largest rank is T2

# %%
U = n1*n2+nx*(nx+1)/2-T2

U
# Out:
# 2.0

# %%
mannwhitneyu(x=df.Rating,
             y=df2.Rating,
             alternative='two-sided')
# Out:
# MannwhitneyuResult(statistic=2.0, pvalue=0.012591911490379684)
